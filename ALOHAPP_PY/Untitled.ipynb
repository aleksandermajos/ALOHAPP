# %%
from TATOEBA_SEN_DOWNLOAD import load_sentences
from TATOEBA_SEN_DOWNLOAD import load_sentences_audio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.conda/envs/BIGAI/lib/python3.10/site-packages/pandas/compat/_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File ~/.conda/envs/BIGAI/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
s_cny_df = load_sentences('DATA/CNY_SEN.xlsx')
s_audio_df = load_sentences_audio('DATA/sentences_with_audio.xlsx')

# %%
del s_audio_df['Unnamed: 0']

# %%
s_audio_df
# Out:
#          Sentence_id  Audio_id    Username          License  \
# 0                 68         2  fucongcong              NaN
# 1                 78    754915    mramosch              NaN
# 2                 85    566395      driini     CC BY-NC 4.0
# 3                 88    592881      driini     CC BY-NC 4.0
# 4                 91    754916    mramosch              NaN
# ...              ...       ...         ...              ...
# 1016768     11044846   1058818          CK  CC BY-NC-ND 3.0
# 1016769     11044847   1058832          CK  CC BY-NC-ND 3.0
# 1016770     11044848   1058831          CK  CC BY-NC-ND 3.0
# 1016771     11044849   1058821          CK  CC BY-NC-ND 3.0
# 1016772     11044850   1058822          CK  CC BY-NC-ND 3.0
#
#                                      Attribution_URL
# 0                                                NaN
# 1                                                NaN
# 2        https://tatoeba.org/deu/user/profile/driini
# ...

# %%
del s_cny_df['Unnamed: 0']

# %%
s_cny_df
# Out:
#       Sentence_id Lang                    Text    Username  \
# 0               2  cmn                 我该去睡觉了。  fucongcong
# 1               3  cmn                 你在干什麼啊？       sysko
# 2               4  cmn                  這是什麼啊？      Martha
# 3               5  cmn  今天是６月１８号，也是Muiriel的生日！       Zifre
# 4               6  cmn           生日快乐，Muiriel！       sysko
# ...           ...  ...                     ...         ...
# 72407    11031502  cmn                  狐狸很可愛！         HRY
# 72408    11039766  cmn           他是他班裡學習最努力的了。     DaoSeng
# 72409    11044297  cmn                您買了輛新車嗎？     DaoSeng
# 72410    11044298  cmn            您新買的是輛嶄新的車嗎？     DaoSeng
# 72411    11044300  cmn              您買了輛全新的車子？     DaoSeng
#
#                 Date_added        Date_modified
# 0                       \N  0000-00-00 00:00:00
# 1                       \N  0000-00-00 00:00:00
# 2      2008-09-08 09:20:59  0000-00-00 00:00:00
# 3                       \N  0000-00-00 00:00:00
# ...

# %%
audio_ids = s_audio_df['Audio_id'].values

# %%
import wget
URL = "https://tatoeba.org/audio/download/"
for i in audio_ids:
    print(i)
    URL_NEW = URL + str(i)
    print(URL_NEW)
    response = wget.download(URL_NEW,'DATA/TATOEBA_AUDIO_ALL/')
# Out:
# 2
# https://tatoeba.org/audio/download/2
# 100% [..............................................................................] 20270 / 20270754915
# https://tatoeba.org/audio/download/754915
# 100% [..............................................................................] 18061 / 18061566395
# https://tatoeba.org/audio/download/566395
# 100% [................................................................................] 9608 / 9608592881
# https://tatoeba.org/audio/download/592881
# 100% [..............................................................................] 11975 / 11975754916
# https://tatoeba.org/audio/download/754916
# 100% [..............................................................................] 16439 / 16439758277
# https://tatoeba.org/audio/download/758277
# 100% [..............................................................................] 17567 / 17567395121
# https://tatoeba.org/audio/download/395121
# ...
